# %%
from astropy import units as u
from astropy.io import fits
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/kyleporter/Desktop/ASTR480/Sp2018/Final Project Codes/Data/OH_SFR_BPT_1000.csv", header=1)

# %%
data
# Out:
#           oh_p50  sfr_tot_p50  bptclass
# 0   -9999.000000    -2.040528        -1
# 1   -9999.000000 -9999.000000        -1
# 2   -9999.000000    -0.619822         1
# 3   -9999.000000    -4.320364        -1
# 4   -9999.000000    -0.135347         3
# 5   -9999.000000 -9999.000000        -1
# 6   -9999.000000    -1.728022        -1
# 7   -9999.000000 -9999.000000        -1
# 8   -9999.000000     0.143602         2
# 9   -9999.000000 -9999.000000         2
# 10  -9999.000000 -9999.000000        -1
# 11  -9999.000000     0.390317         2
# 12  -9999.000000    -3.608739        -1
# 13  -9999.000000    -3.419821        -1
# 14  -9999.000000 -9999.000000        -1
# 15      8.629640    -2.687118         1
# 16  -9999.000000    -1.012547         5
# 17  -9999.000000    -4.977770         2
# 18  -9999.000000    -1.305906        -1
# 19      8.953279    -0.457054         1
# 20      9.066183     0.683255         1
# 21  -9999.000000    -1.562377         2
# ...

# %%
fig, ax = plt.subplots()
for i in data.values:
    if((i[0] != -9999) & (i[1] != -9999)):
        ax.scatter(i[0], i[1])
ax.set_xlabel("OH")
ax.set_ylabel("SFR")
# Out:
# Text(0,0.5,'SFR')

# %%
fig, ax = plt.subplots()
for i in data.values:
    if((i[1] != -9999) & (i[2] != -1)):
        ax.scatter(i[2], i[1], alpha=0.05)
ax.set_xlabel("BPT Class")
ax.set_ylabel("SFR")
# Out:
# Text(0,0.5,'SFR')

# %%
fig, ax = plt.subplots()
for i in data.values:
    if((i[0] != -9999) & (i[2] != -1)):
        ax.scatter(i[2], i[0])
ax.set_xlabel("BPT Class")
ax.set_ylabel("OH")
# Out:
# Text(0,0.5,'OH')
