# %%
from astropy import units as u
from astropy.io import fits
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/kyleporter/Desktop/ASTR480/Sp2018/SDSS_Lab/M67PHOT.csv", header=1)

# %%
data["u"]
# Out:
# 0        22.13848
# 1        22.87586
# 2        24.84452
# 3        24.33881
# 4        23.26823
# 5        22.90342
# 6        23.06646
# 7        24.22585
# 8        25.47607
# 9        25.05697
# 10       24.14766
# 11       27.70401
# 12       24.86194
# 13       25.02711
# 14       25.89408
# 15       23.63490
# 16       16.89168
# 17       16.89629
# 18       16.89104
# 19       21.79484
# 20       19.78284
# 21       19.87018
# 22       21.54298
# 23       22.30587
# 24       22.18800
# 25       24.61361
# 26       25.42338
# 27       25.21231
# 28       23.53811
# 29       24.78174
#            ...
# 10274    22.36612
# 10275    26.21894
# 10276    22.42763
# 10277    22.03096
# 10278    23.18355
# 10279    23.86314
# 10280    25.13032
# 10281    25.55410
# 10282    25.32174
# 10283    24.08417
# 10284    23.13617
# 10285    22.36818
# 10286    23.12696
# 10287    23.06949
# 10288    26.00295
# 10289    25.17790
# 10290    24.58892
# 10291    23.56590
# 10292    24.07405
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(data["ra"], data["dec"], alpha = 0.1)
ax.set_xlabel("RA")
ax.set_ylabel("DEC")
# Out:
# Text(0,0.5,'DEC')

# %%
fig, ax = plt.subplots()
ax.scatter(data["u"] - data["g"], data["g"], alpha = 0.1)
ax.set_xlabel("u - g")
ax.set_ylabel("g")
# Out:
# Text(0,0.5,'g')

# %%
fig, ax = plt.subplots()
ax.scatter(data["r"] - data["i"], data["r"], alpha = 0.1)
ax.set_xlabel("r - i")
ax.set_ylabel("r")
ax.set_xlim(-4, 4)
ax.set_ylim(-10, 50)
# Out:
# (-10, 50)
